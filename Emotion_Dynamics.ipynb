# %%
import pandas as pd
import string

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv(r"/content/drive/MyDrive/senti-twitter-pred/preprocessed_entire_df.csv")

# %%
df.shape
# Out:
# (757643, 4)

# %%
type(df['Tweets_tokens'][0])
# Out:
# str

# %%
df.loc[731609,'Lemma_Tweets']="".join(filter(lambda x: x not in string.punctuation,df.loc[731609,'Lemma_Tweets']))

df.loc[731609,'Lemma_Tweets']
# Out:
# 'the current price bitcoin the current price bcash btc the current price bcashsv bcash'

# %%
df.loc[731610,'Lemma_Tweets']="".join(filter(lambda x: x not in string.punctuation,df.loc[731610,'Lemma_Tweets']))

df.loc[731610,'Lemma_Tweets']
# Out:
# 'btcusdt crypto btc bitcoin quick look btc i guess now feb utc good time buy btc donate btc bcqeenywqcdxqfqdcyygwrmylxla'

# %%
df=df[df['Lemma_Tweets'].isna()==False]

# %%
df['Lemma_Tweets']=df['Lemma_Tweets'].apply(lambda y:filter(lambda x:x not in string.punctuation,y))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Lemma_Tweets']=df['Lemma_Tweets'].apply(lambda x:"".join(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['speaker']='Twitter'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(5)
# Out:
#                                               Tweets  \
# 0   Current Bitcoin Price BTC Crypto\nIndicators ...
# 1  Updated Bitcoin transaction fees \n    \nBCH N...
# 2  Candle day  closed\n\nOpen  \nHigh  \nLow  \nC...
# 3   Current Bitcoin Price BTC Crypto\nIndicators ...
# 4  Bitcoin lack chain privacy scare whales away g...
#
#                         Date  \
# 0  2022-04-04 23:59:59+00:00
# 1  2022-04-04 23:59:50+00:00
# 2  2022-04-04 23:59:00+00:00
# 3  2022-04-04 23:58:58+00:00
# 4  2022-04-04 23:58:58+00:00
#
#                                        Tweets_tokens  \
# 0  current bitcoin price btc crypto indicators da...
# 1  updated bitcoin transaction fees bch next bloc...
# 2  candle day closed open high low close change b...
# 3  current bitcoin price btc crypto indicators da...
# 4  bitcoin lack chain privacy scare whales away g...
#
#                                         Lemma_Tweets  speaker
# 0  current bitcoin price btc crypto indicator dai...  Twitter
# ...

# %%
df=df.loc[:,['Tweets','Date','Lemma_Tweets','speaker']]

# %%
df.columns=['Tweets','Date','text','speaker']

# %%
df['text'].isna().any()
# Out:
# False

# %%
df['text']=df['text'].apply(lambda x:x.strip())

# %%
df[df['text']==""]
# Out:
# Empty DataFrame
# Columns: [Tweets, Date, text, speaker]
# Index: []

# %%
df.to_csv("/content/drive/MyDrive/senti-twitter-pred/final_file_for_ED.csv")
