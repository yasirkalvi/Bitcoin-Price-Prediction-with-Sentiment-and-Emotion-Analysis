# %%
import pandas as pd
import datetime
from datetime import datetime
import scipy.stats
from datetime import timedelta

# %%
anger=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Anger.csv",index_col=False)
anti=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Anticipation.csv",index_col=False)
anti=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Anticipation.csv",index_col=False)
dis=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Disgust.csv",index_col=False)
fear=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Fear.csv",index_col=False)
joy=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Joy.csv",index_col=False)
pos=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Positive.csv",index_col=False)
neg=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Negative.csv",index_col=False)
sad=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Sadness.csv",index_col=False)
sur=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Surprise.csv",index_col=False)
trust=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/Emotion_Dynamics_Result/Trust.csv",index_col=False)

# %%
print(anger.shape)
# Out:
# (731608, 9)

# %%
print(anti.shape)
# Out:
# (731608, 9)

# %%
print(dis.shape)
# Out:
# (731608, 9)

# %%
print(fear.shape)
# Out:
# (731608, 9)

# %%
print(joy.shape)
# Out:
# (731608, 9)

# %%
print(pos.shape)
# Out:
# (731608, 9)

# %%
print(neg.shape,sad.shape,sur.shape,trust.shape)
# Out:
# (731608, 9) (731608, 9) (731608, 9) (731608, 9)

# %%
print(anger['Date'][731607])
# Out:
# 2022-02-01 00:00:00+00:00

# %%
print(anger['Date'][0])
# Out:
# 2022-04-04 23:59:59+00:00

# %%
len(anger['Date'].unique())
# Out:
# 660965

# %%
anger['date']=anger['Date'].apply(lambda x:x[0:19])
anti['date']=anti['Date'].apply(lambda x:x[0:19])
dis['date']=dis['Date'].apply(lambda x:x[0:19])
fear['date']=fear['Date'].apply(lambda x:x[0:19])
joy['date']=joy['Date'].apply(lambda x:x[0:19])
pos['date']=pos['Date'].apply(lambda x:x[0:19])
neg['date']=neg['Date'].apply(lambda x:x[0:19])
sad['date']=sad['Date'].apply(lambda x:x[0:19])
sur['date']=sur['Date'].apply(lambda x:x[0:19])
trust['date']=trust['Date'].apply(lambda x:x[0:19])

# %%
anger['date'][0]
# Out:
# '2022-04-04 23:59:59'

# %%
anger['date']=anger['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
anti['date']=anti['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
dis['date']=dis['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
fear['date']=fear['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
joy['date']=joy['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
pos['date']=pos['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
neg['date']=neg['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
sad['date']=sad['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
sur['date']=sur['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))
trust['date']=trust['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))

# %%
type(anger['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
anger['date'].head(5)
# Out:
# 0   2022-04-04 23:59:00
# 1   2022-04-04 23:59:00
# 2   2022-04-04 23:59:00
# 3   2022-04-04 23:58:00
# 4   2022-04-04 23:58:00
# Name: date, dtype: datetime64[ns]

# %%
anger=anger.iloc[:,1:]

# %%
anger_avg_emo=pd.DataFrame(anger.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
anti_avg_emo=pd.DataFrame(anti.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
dis_avg_emo=pd.DataFrame(dis.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
fear_avg_emo=pd.DataFrame(fear.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
joy_avg_emo=pd.DataFrame(joy.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
pos_avg_emo=pd.DataFrame(pos.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
neg_avg_emo=pd.DataFrame(neg.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
sad_avg_emo=pd.DataFrame(sad.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
sur_avg_emo=pd.DataFrame(sur.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))
trust_avg_emo=pd.DataFrame(trust.groupby('date',as_index=False).agg(avg_emo=('avgLexVal','mean')))

# %%
anger_avg_emo.head()
# Out:
#                  date   avg_emo
# 0 2022-02-01 00:00:00  0.051861
# 1 2022-02-01 00:01:00  0.016529
# 2 2022-02-01 00:02:00  0.018519
# 3 2022-02-01 00:03:00  0.061218
# 4 2022-02-01 00:04:00  0.041667

# %%
crypto=pd.read_csv("/content/drive/MyDrive/senti-twitter-pred/BTC Dataset/BTCUSD_1h.csv")

# %%
crypto=crypto.iloc[:,1:]

# %%
crypto['date']=crypto['date'].apply(lambda x:pd.to_datetime(datetime.strftime(pd.to_datetime(x),"%Y-%m-%d %H:%M")))

# %%
type(crypto['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
crypto_avg=pd.DataFrame(crypto.groupby('date',as_index=False).agg(({'open' : ['mean'], 'close' : ['mean'],'high' : ['mean'],'low':['mean'],'Volume BTC':['mean']})))

# %%
crypto_avg.columns=['date','open','close','high','low','volume']
crypto_avg.head(5)
# Out:
#                  date      open     close      high       low      volume
# 0 2022-01-02 00:00:00  38483.56  38384.86  38669.80  38311.51  116.252959
# 1 2022-01-02 01:00:00  38368.40  38265.72  38436.33  38218.04   38.404059
# 2 2022-01-02 02:00:00  38277.05  38495.46  38539.02  38232.25   28.839977
# 3 2022-01-02 03:00:00  38490.09  38647.57  38668.35  38433.68   41.170142
# 4 2022-01-02 04:00:00  38625.27  38592.04  38692.19  38494.97   27.355586

# %%
merged_dataset_ang=anger_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_anti=anti_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_dis=dis_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_fear=fear_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_joy=joy_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_pos=pos_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_neg=neg_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_sad=sad_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_sur=sur_avg_emo.merge(crypto_avg,on='date',how='inner')
merged_dataset_trust=trust_avg_emo.merge(crypto_avg,on='date',how='inner')

# %%
merged_dataset_ang.columns=['date','avg_emo','open','close','high','low','volume']

merged_dataset_anti.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_dis.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_fear.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_joy.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_pos.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_neg.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_sad.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_sur.columns=['date','avg_emo','open','close','high','low','volume']
merged_dataset_trust.columns=['date','avg_emo','open','close','high','low','volume']

# %%
merged_dataset_ang.columns.name = 'anger'
merged_dataset_anti.columns.name = 'anti'
merged_dataset_dis.columns.name = 'dis'
merged_dataset_fear.columns.name = 'fear'
merged_dataset_joy.columns.name = 'joy'
merged_dataset_pos.columns.name = 'pos'
merged_dataset_neg.columns.name = 'neg'
merged_dataset_sad.columns.name = 'sad'
merged_dataset_sur.columns.name = 'sur'
merged_dataset_trust.columns.name = 'trust'

# %%
emo=[merged_dataset_ang,merged_dataset_anti,merged_dataset_dis,merged_dataset_fear,merged_dataset_joy,merged_dataset_pos,merged_dataset_neg,merged_dataset_sad,merged_dataset_sur,merged_dataset_trust]

# %%
l=[]
cols=merged_dataset_ang.columns[2:7]
for i in emo:
  for col in cols:
    corr,p=scipy.stats.pearsonr(i['avg_emo'],i[col])
    if (p<0.05):
      l.append([corr,p,i.columns.name,col])

# %%
signi_corr=pd.DataFrame(l)
signi_corr.head(5)
print(signi_corr.shape)
signi_corr.columns=['corr_value','p-value','emotion','crypto_val']
# Out:
# (15, 4)

# %%
signi_corr.head(15)
# Out:
#     corr_value   p-value emotion crypto_val
# 0    -0.092203  0.002708   anger       open
# 1    -0.093763  0.002288   anger      close
# 2    -0.089988  0.003425   anger       high
# 3    -0.096793  0.001638   anger        low
# 4     0.060863  0.048006   anger     volume
# 5    -0.095429  0.001906    fear       open
# 6    -0.096724  0.001651    fear      close
# 7    -0.093360  0.002390    fear       high
# 8    -0.099921  0.001149    fear        low
# 9     0.064270  0.036779    fear     volume
# 10   -0.099141  0.001256     sad       open
# 11   -0.100730  0.001046     sad      close
# 12   -0.095694  0.001851     sad       high
# 13   -0.103285  0.000776     sad        low
# 14    0.093969  0.002237     sad     volume

# %%
#signi_corr.to_csv("/content/drive/MyDrive/senti-twitter-pred/sig_corr_no_lag.csv")

# %%
 def lag_data(crypto_data,lag): 
   crypto_data.set_index('date', inplace=True)
   crypto_data['lag_open'] = crypto_data.shift(lag)['open'].values
   
   crypto_data['lag_close'] = crypto_data.shift(lag)['close'].values
   
   crypto_data['lag_high'] = crypto_data.shift(lag)['high'].values
   
   crypto_data['lag_low'] = crypto_data.shift(lag)['low'].values
   
   crypto_data['lag_volume'] = crypto_data.shift(lag)['volume'].values
   
   crypto_data.reset_index(inplace = True)
   return (crypto_data)

# %%
def merge_data(cryp_data,emo_data):
  df_final = pd.merge(cryp_data,emo_data, how='inner', on='date')
  return(df_final)

# %%
crypto_lag_data=lag_data(crypto_avg,7)

# %%
crypto_lag_data.head(10)
# Out:
#                  date      open     close      high       low      volume  \
# 0 2022-01-02 00:00:00  38483.56  38384.86  38669.80  38311.51  116.252959
# 1 2022-01-02 01:00:00  38368.40  38265.72  38436.33  38218.04   38.404059
# 2 2022-01-02 02:00:00  38277.05  38495.46  38539.02  38232.25   28.839977
# 3 2022-01-02 03:00:00  38490.09  38647.57  38668.35  38433.68   41.170142
# 4 2022-01-02 04:00:00  38625.27  38592.04  38692.19  38494.97   27.355586
# 5 2022-01-02 05:00:00  38592.04  38479.04  38650.00  38472.59   30.042273
# 6 2022-01-02 06:00:00  38476.24  38326.73  38517.77  38250.00   40.695827
# 7 2022-01-02 07:00:00  38316.31  38468.39  38495.41  38316.31   37.847131
# 8 2022-01-02 08:00:00  38464.94  38622.46  38637.18  38430.99   36.714848
# 9 2022-01-02 09:00:00  38609.10  38278.04  39115.16  38242.96  246.132591
#
#    lag_open  lag_close  lag_high   lag_low  lag_volume
# 0       NaN        NaN       NaN       NaN         NaN
# 1       NaN        NaN       NaN       NaN         NaN
# 2       NaN        NaN       NaN       NaN         NaN
# 3       NaN        NaN       NaN       NaN         NaN
# 4       NaN        NaN       NaN       NaN         NaN
# 5       NaN        NaN       NaN       NaN         NaN
# 6       NaN        NaN       NaN       NaN         NaN
# 7  38483.56   38384.86  38669.80  38311.51  116.252959
# 8  38368.40   38265.72  38436.33  38218.04   38.404059
# 9  38277.05   38495.46  38539.02  38232.25   28.839977

# %%
anger_merged_lag=merge_data(crypto_lag_data,anger_avg_emo)
anti_merged_lag=merge_data(crypto_lag_data,anti_avg_emo)
dis_merged_lag=merge_data(crypto_lag_data,dis_avg_emo)
fear_merged_lag=merge_data(crypto_lag_data,fear_avg_emo)
joy_merged_lag=merge_data(crypto_lag_data,anger_avg_emo)
trust_merged_lag=merge_data(crypto_lag_data,trust_avg_emo)
sad_merged_lag=merge_data(crypto_lag_data,sad_avg_emo)
sur_merged_lag=merge_data(crypto_lag_data,sur_avg_emo)
pos_merged_lag=merge_data(crypto_lag_data,pos_avg_emo)
neg_merged_lag=merge_data(crypto_lag_data,neg_avg_emo)

# %%
anger_merged_lag.columns[6:11]
# Out:
# Index(['lag_open', 'lag_close', 'lag_high', 'lag_low', 'lag_volume'], dtype='object')

# %%
def lag_corr(merged_data,emo_name):
  l2=[]
  cols=merged_data.columns[6:11]
  for col in cols:
    corr,p=scipy.stats.pearsonr(merged_data['avg_emo'],merged_data[col])
    if (p<0.05):
      l2.append([corr,p,emo_name,col])
  return(l2)

# %%
sig_corr_lag_anger=lag_corr(anger_merged_lag,'anger')
sig_corr_lag_anger=pd.DataFrame(sig_corr_lag_anger)
sig_corr_lag_anger.head(5)
print(sig_corr_lag_anger.shape)
sig_corr_lag_anger.columns=['corr_value','p-value','emotion','crypto_val']
# Out:
# (5, 4)

# %%
sig_corr_lag_anti=lag_corr(anti_merged_lag,'anticipation')
sig_corr_lag_anti=pd.DataFrame(sig_corr_lag_anti)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_anti.shape)
#sig_corr_lag_anti.columns=['corr_value','p-value','emotion','crypto_val']
# Out:
# (0, 0)

# %%
sig_corr_lag_dis=lag_corr(dis_merged_lag,'disgust')
sig_corr_lag_dis=pd.DataFrame(sig_corr_lag_dis)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_dis.shape)
# Out:
# (1, 4)

# %%
sig_corr_lag_dis.columns=['corr_value','p-value','emotion','crypto_val']

# %%
sig_corr_lag_fear=lag_corr(fear_merged_lag,'fear')
sig_corr_lag_fear=pd.DataFrame(sig_corr_lag_fear)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_fear.shape)
# Out:
# (5, 4)

# %%
sig_corr_lag_fear.columns=['corr_value','p-value','emotion','crypto_val']

# %%
sig_corr_lag_joy=lag_corr(joy_merged_lag,'joy')
sig_corr_lag_joy=pd.DataFrame(sig_corr_lag_joy)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_joy.shape)
# Out:
# (5, 4)

# %%
sig_corr_lag_joy.columns=['corr_value','p-value','emotion','crypto_val']

# %%
sig_corr_lag_trust=lag_corr(trust_merged_lag,'trust')
sig_corr_lag_trust=pd.DataFrame(sig_corr_lag_trust)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_trust.shape)
# Out:
# (0, 0)

# %%
sig_corr_lag_sad=lag_corr(sad_merged_lag,'sad')
sig_corr_lag_sad=pd.DataFrame(sig_corr_lag_sad)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_sad.shape)
# Out:
# (4, 4)

# %%
sig_corr_lag_sad.columns=['corr_value','p-value','emotion','crypto_val']

# %%
sig_corr_lag_sur=lag_corr(sur_merged_lag,'sur')
sig_corr_lag_sur=pd.DataFrame(sig_corr_lag_sur)
#sig_corr_lag_anti.head(5)
print(sig_corr_lag_sur.shape)
# Out:
# (0, 0)

# %%
#sig_corr_lag_sur.columns=['corr_value','p-value','emotion','crypto_val']

# %%
c1=pd.concat([sig_corr_lag_anger,sig_corr_lag_fear],axis=0)
c2=pd.concat([c1,sig_corr_lag_joy],axis=0)
c3=pd.concat([c2,sig_corr_lag_sad],axis=0)
c4=pd.concat([c3,sig_corr_lag_sur],axis=0)

# %%
c4.head(20)
# Out:
#    corr_value   p-value emotion  crypto_val
# 0   -0.097338  0.001541   anger    lag_open
# 1   -0.096048  0.001780   anger   lag_close
# 2   -0.094728  0.002059   anger    lag_high
# 3   -0.099134  0.001257   anger     lag_low
# 4    0.079067  0.010159   anger  lag_volume
# 0   -0.101519  0.000955    fear    lag_open
# 1   -0.100247  0.001106    fear   lag_close
# 2   -0.100014  0.001136    fear    lag_high
# 3   -0.102582  0.000843    fear     lag_low
# 4    0.099483  0.001208    fear  lag_volume
# 0   -0.097338  0.001541     joy    lag_open
# 1   -0.096048  0.001780     joy   lag_close
# 2   -0.094728  0.002059     joy    lag_high
# 3   -0.099134  0.001257     joy     lag_low
# 4    0.079067  0.010159     joy  lag_volume
# 0   -0.089608  0.003565     sad    lag_open
# 1   -0.087772  0.004312     sad   lag_close
# 2   -0.090123  0.003377     sad    lag_high

# %%
c4.to_csv("/content/drive/MyDrive/senti-twitter-pred/sig_corr_lag_7d.csv",index=False)
