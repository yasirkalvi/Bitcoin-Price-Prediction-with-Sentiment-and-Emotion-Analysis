# %%
import pandas as pd

# %%
##Importing tweets csv:
file='/content/drive/MyDrive/senti-twitter-pred/data/tweet.csv'
df = pd.read_csv (file)
print (df)
# Out:
#                                                    Tweets  \
# 0       19804) Current #Bitcoin Price is $46609 #BTC #...
# 1       Updated Bitcoin transaction fees: \n    \nBCH ...
# 2       Candle of day 04/04/2022 closed.\n\nOpen: $ 46...
# 3       19803) Current #Bitcoin Price is $46606 #BTC #...
# 4       #Bitcoin lack of on chain #privacy will only s...
# ...                                                   ...
# 757635  Average Bitcoin market price is: USD 38,521.79...
# 757636  Current BTC Dominance: 41.64% #Bitcoin #Altcoi...
# 757637  Bitcoin: $38494.66\n💚 +53.84 last 1 Hour (+0.1...
# 757638                         Buy Bitcoin $BTC @ 38466.9
# 757639                        Effect of money on Bitcoin!
#
#                              Date
# 0       2022-04-04 23:59:59+00:00
# 1       2022-04-04 23:59:50+00:00
# 2       2022-04-04 23:59:00+00:00
# 3       2022-04-04 23:58:58+00:00
# 4       2022-04-04 23:58:58+00:00
# ...                           ...
# ...

# %%
#Import the libraries
import tweepy
from textblob import TextBlob
#from wordcloud import WorldCloud
#!pip install wordCloud

import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt 
plt.style.use("fivethirtyeight")
import nltk
import nltk.tokenize

# %%
from nltk.tokenize import TweetTokenizer

# %%
#Cleaning

from nltk.tokenize import TweetTokenizer
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')

##Functio\n to clean the tweets:
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) #Remvoded @mentions

    #text = re.sub(r'#', '', text) #Removing the '#' symbol

    text = re.sub(r'RT[\s]+', '', text) #Removing RT

    text = re.sub(r'https?:\/\/\S+', '', text) #Remove the hyper link

    #text = text.lower() #converting text to lower case

    text = re.sub("[0-9]","", text) #removing digits
    
    text = re.sub(r'[^\w\s]',"", text) #removing punctuation

    #text = re.sub("[^a-z0-9]"," ", text) #removing all non-alphanumeric characters
    
    pattern = re.compile(r'\b(' + r'|'.join(stopword) + r')\b\s*')
    text = pattern.sub('', text) #Remove stop words

    #text = [word for word in text if word not in stopword]

    ##pos tagging
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Cleaning the text
df['Tweets']= df['Tweets'].apply(cleanTxt)

#Show the cleaned text
df['Tweets']
# Out:
# 0          Current Bitcoin Price BTC Crypto\nIndicators ...
# 1         Updated Bitcoin transaction fees \n    \nBCH N...
# 2         Candle day  closed\n\nOpen  \nHigh  \nLow  \nC...
# 3          Current Bitcoin Price BTC Crypto\nIndicators ...
# 4         Bitcoin lack chain privacy scare whales away g...
#                                 ...
# 757635               Average Bitcoin market price USD  EUR
# 757636    Current BTC Dominance  Bitcoin Altcoin Cryptoc...
# 757637    Bitcoin \n  last  Hour \n  last  Hours \n  las...
# 757638                                    Buy Bitcoin BTC
# 757639                                 Effect money Bitcoin
# Name: Tweets, Length: 757640, dtype: object

# %%
def tokenizer(text):

    text = TweetTokenizer(   #using tweet tokenizer from nltk library

        preserve_case=False, #preserve_case lower-cases the letters

        strip_handles=True, #strip_handles removes the twitter-handles

        reduce_len=True).tokenize(text) #reduce_len limits the number of times a character can be repeated to three
    
    return text

# %%
#Tokenising the text
df['Tweets_tokens']= df['Tweets'].apply(tokenizer)

#Show the cleaned text
df['Tweets_tokens']
# Out:
# 0         [current, bitcoin, price, btc, crypto, indicat...
# 1         [updated, bitcoin, transaction, fees, bch, nex...
# 2         [candle, day, closed, open, high, low, close, ...
# 3         [current, bitcoin, price, btc, crypto, indicat...
# 4         [bitcoin, lack, chain, privacy, scare, whales,...
#                                 ...
# 757635          [average, bitcoin, market, price, usd, eur]
# 757636    [current, btc, dominance, bitcoin, altcoin, cr...
# 757637    [bitcoin, last, hour, last, hours, last, hours...
# 757638                                  [buy, bitcoin, btc]
# 757639                             [effect, money, bitcoin]
# Name: Tweets_tokens, Length: 757640, dtype: object

# %%
##Lematization with POS Tagging
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# !pip install --user -U nltk
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#!pip install --user -U nltk

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
def lemmatizer(tokens):

    from nltk.corpus import wordnet

    def get_wordnet_pos(treebank_tag):

        if treebank_tag.startswith('J'):
            return wordnet.ADJ
        elif treebank_tag.startswith('V'):
            return wordnet.VERB
        elif treebank_tag.startswith('N'):
            return wordnet.NOUN
        elif treebank_tag.startswith('R'):
            return wordnet.ADV
        else:
            return None # for easy if-statement 



    from nltk.stem.wordnet import WordNetLemmatizer

    lemmatizer = WordNetLemmatizer()

    l=[]
    for token, tag in pos_tag(tokens):

        wntag = get_wordnet_pos(tag)
        
        
        if wntag is None:# not supply tag in case of None
            l.append(lemmatizer.lemmatize(token))
        else:
            l.append(lemmatizer.lemmatize(token, pos=wntag))
            
    
    return l

# %%
df['Lemma_Tweets'] = df['Tweets_tokens'].apply(lambda x:lemmatizer(x))

print(df['Lemma_Tweets'])
print(df['Tweets'])
# Out:
# 0         [current, bitcoin, price, btc, crypto, indicat...
# 1         [updated, bitcoin, transaction, fee, bch, next...
# 2         [candle, day, close, open, high, low, close, c...
# 3         [current, bitcoin, price, btc, crypto, indicat...
# 4         [bitcoin, lack, chain, privacy, scare, whale, ...
#                                 ...
# 757635          [average, bitcoin, market, price, usd, eur]
# 757636    [current, btc, dominance, bitcoin, altcoin, cr...
# 757637    [bitcoin, last, hour, last, hour, last, hour, ...
# 757638                                  [buy, bitcoin, btc]
# 757639                             [effect, money, bitcoin]
# Name: Lemma_Tweets, Length: 757640, dtype: object
# 0          Current Bitcoin Price BTC Crypto\nIndicators ...
# 1         Updated Bitcoin transaction fees \n    \nBCH N...
# 2         Candle day  closed\n\nOpen  \nHigh  \nLow  \nC...
# 3          Current Bitcoin Price BTC Crypto\nIndicators ...
# ...

# %%
##Applying NRCLex

# %%
# !pip install NRCLex
from nrclex import NRCLex
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 396 kB 14.9 MB/s
# ...
#   Created wheel for NRCLex: filename=NRCLex-3.0.0-py3-none-any.whl size=43329 sha256=046f301b162fa31eceb52a05965aa687af5fe8ab16580d0161fc754805fc5a9e
#   Stored in directory: /root/.cache/pip/wheels/af/2c/9c/dfa19d1b65326c520b32850a9311f6d4eda679ac04dba26081
# Successfully built NRCLex
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#for tweet in df['Tweets']:
    #print(NRCLex(tweet).top_emotions)
# Out:
# Streaming output truncated to the last 5000 lines.
# [('negative', 0.5), ('sadness', 0.5)]
# [('trust', 0.4)]
# [('anticipation', 1.0)]
# [('trust', 0.3333333333333333)]
# [('trust', 0.2), ('positive', 0.2)]
# [('trust', 0.5)]
# [('anticipation', 0.8571428571428571)]
# [('positive', 1.0)]
# [('positive', 1.0)]
# [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
# [('positive', 1.0)]
# [('positive', 1.0)]
# [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
# [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
# [('positive', 1.0)]
# [('positive', 1.0)]
# [('fear', 1.0)]
# [('positive', 0.4)]
# ...

# %%
#text_object = NRCLex(text)
#NRCLex.append_text(df['Lemma_Tweets'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f3db9375c6d7> in <module>
# ----> 1 text_object = NRCLex(text)
#       2 NRCLex.append_text(df['Lemma_Tweets'])
#
# NameError: name 'text' is not defined

# %%
#text = text_object.load_token_list(list_of_tokens: list)
# Out:
#   File "<ipython-input-26-1a788d3d861c>", line 1
#     text = text_object.load_token_list(list_of_tokens: list)
#                                                      ^
# SyntaxError: invalid syntax

# %%
#text = 'i am very happy'
#text_object(text).top_emotions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-2a3a8b1a785e> in <module>
#       1 text = 'i am very happy'
# ----> 2 text_object(text).top_emotions
#
# TypeError: 'NRCLex' object is not callable

# %%
#text_object.load_token_list(df['Lemma_Tweets'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-d3c3bb4f2d33> in <module>
# ----> 1 text_object.load_token_list(df['Lemma_Tweets'])
#
# AttributeError: 'NRCLex' object has no attribute 'load_token_list'

# %%
# !pip install NRCLex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def get_emotions(text, dataframe):
    import operator
    """
    Function that will take a text at return a dataframe of emotions (excluding positive and negative)
    Params:
        text (str): The tweet of interest
        dataframe (Pandas DataFrame): The emotions dataframe to add values
        
    Return:
        Updated dataframe with the new row of interest
    """
    nrc_text = NRCLex(text)
    nrc_dict = nrc_text.affect_frequencies
    nrc_dict.pop('positive', None)
    nrc_dict.pop('negative', None)
    nrc_dict.pop('anticip', None)
    nrc_max_emotion = max(nrc_dict.items(), key=operator.itemgetter(1))[0]
    nrc_dict["max_emotion"] = nrc_max_emotion
    dataframe = dataframe.append(nrc_dict, ignore_index= True)
    return dataframe

# %%
#emotion_df = pd.DataFrame(columns = ['fear', 'anger', 'trust', 'surprise', 'sadness', 'disgust', 'joy', 'anticipation', 'max_emotion'])

#df['Tweets']=df['Tweets'].apply(lambda x:get_emotions(text, emotion_df))

# %%
df.shape
# Out:
# (757640, 5)

# %%
df.to_csv("/content/drive/MyDrive/senti-twitter-pred/data/preprocessed_entire_df.csv",index=False)

# %%
emotion_df
# Out:
#            fear     anger     trust  surprise  sadness  disgust       joy  \
# 0      0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 1      0.000000  0.000000  1.000000  0.000000      0.0      0.0  0.000000
# 2      0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 3      0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 4      0.083333  0.083333  0.083333  0.166667      0.0      0.0  0.083333
# ...         ...       ...       ...       ...      ...      ...       ...
# 47842  0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 47843  0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 47844  0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
# 47845  0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.333333
# 47846  0.000000  0.000000  0.000000  0.000000      0.0      0.0  0.000000
#
#        anticipation   max_emotion
# 0               NaN          fear
# ...
